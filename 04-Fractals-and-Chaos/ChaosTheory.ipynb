# %% [markdown]
# ## HW08-04-Chaos
# ## Paimah Safarian 96109628

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import random
import math

# %%
n   = 100
x   = np.zeros(n)
x_plot = []
y_plot = []
x[0] = 0.09
r   = 0.9

for i in range(n-1):
    x[i+1] = 4 * r * x[i] * (1 - x[i])
    x_plot.append(x[i])
    y_plot.append(x[i+1])
    x_plot.append(x[i+1])
    y_plot.append(x[i+1])
    
plt.plot(x_plot, y_plot, c = 'black')
x_curve = np.arange(0, 1, 0.01) 
plt.plot(x_curve, x_curve, c = 'orange')
plt.plot(x_curve, 4 * r * x_curve * (1 - x_curve), c = 'forestgreen')

plt.savefig("reach.png")

# %%
# returns the value of x after n steps initiating from a random x
def final_x(n, r):
    x = random.random()
    for i in range(n-1):
        x = 4 * r * x * (1 - x)
    return x

# %%
# %%time

r = np.arange(0, 1, 0.001)
repeat = 300
x_plot = []
y_plot = []

for i in range(np.size(r)):
    for j in range(repeat):
        x_plot.append(r[i])
        y_plot.append(final_x(100, r[i]))

plt.scatter(x_plot, y_plot, s = 0.1, c = 'teal')

plt.title("Bifurcation Diagram")
plt.xlabel("$r$")
plt.ylabel("$x$")

plt.savefig("bifurcation.png")
# Out:
# Wall time: 1min 6s

# %%
plt.scatter(x_plot, y_plot, s = 0.1, c = 'teal')
plt.vlines([0.963] , 0 , 1 , linestyle='dashed' , color = 'blue' , linewidth = 0.6 , label = 'r = 0.880')

plt.title("Bifurcation Diagram")
plt.xlabel("$r$")
plt.ylabel("$x$")
# Out:
# Text(0, 0.5, '$x$')

# %%
# %%time

plt.scatter(x_plot, y_plot, s = 0.003, c = 'greenyellow')

plt.vlines([0.745], 0 , 1 , linestyle='dashed' , color ='Black' , linewidth = 0.6 , label = 'r = 0.745')
plt.vlines([0.855], 0 , 1 , linestyle='dashed' , color = 'red' , linewidth = 0.6 , label = 'r=0.855')
plt.vlines([0.890] , 0 , 1 , linestyle='dashed' , color = 'blue' , linewidth = 0.6 , label = 'r = 0.880')
plt.vlines([0.963] , 0 , 1 , linestyle='dashed' , color = 'teal' , linewidth = 0.6 , label = 'r = 0.963')

plt.title("Bifurcation Diagram")
plt.xlabel("$r$")
plt.ylabel("$x$")
plt.legend()

plt.savefig("bifurcation02.png")
# Out:
# Wall time: 9.11 s

# %%
np.where(y_plot == 0.5)
# Out:
# (array([], dtype=int64),)

# %%
# %%time

plt.scatter(x_plot, y_plot, s = 0.003, c = 'greenyellow')

plt.plot([0.805 , 0.805] , [0.5 , 0.81] , linestyle = '-' , color = 'purple' , linewidth = 0.7 , label = 'd1 = 0.31')
plt.plot([0.876 , 0.876] , [0.5 , 0.38] , linestyle = '-' , color = 'green' , linewidth = 0.7 , label = 'd2 = 0.12')
plt.plot([0 , 1] , [0.5 , 0.5] , linestyle = '-' , linewidth = 0.6 )

plt.title("Bifurcation Diagram $\u03B1$")
plt.xlabel("$r$")
plt.ylabel("$x$")
plt.legend()

plt.savefig("bifurcation03.png")
# Out:
# Wall time: 9.35 s

# %%
#differential equation solver functions:

def euler(step , x0 , v0):
    h = t_max / step
    v = np.zeros(step)
    x = np.zeros(step)
    t = np.arange(step) * h 
    x[0] = x0
    v[0] = v0
    for i in range(step-1):
        v[i+1] = v[i] - x[i] * h
        x[i+1] = x[i] + v[i] * h       
    return x,v,t

def euler_kremer(step , x0 , v0):
    h = t_max / step
    v = np.zeros(step)
    x = np.zeros(step)
    t = np.arange(step) * h 
    x[0] = x0
    v[0] = v0
    for i in range(step-1):
        v[i+1] = v[i] - x[i] * h
        x[i+1] = x[i] + v[i+1] * h
    return x,v,t

def verlet(step , x0 , v0):
    h = t_max / step
    v = np.zeros(step)
    x = np.zeros(step)
    t = np.arange(step) * h 
    x[0] = x0
    x[1] = x0 + v0 * h
    v[0] = v0
    for i in range(1 , step-1):
        x[i+1] = 2 * x[i] - x[i-1] - x[i] * (h**2)
    for i in range(1 , step-1):
        v[i] = (x[i+1] - x[i-1]) / (2 * h)     
    return x,v,t    
    
def fast_verlet(N , x0 , v0):
    h = t_max / step
    v = np.zeros(step)
    x = np.zeros(step)
    t = np.arange(step) * h 
    x[0] = x0
    v[0] = v0
    for i in range(step-1):
        x[i+1] = x[i] + v[i] * h - x[i] * (h**2 /2)
        v[i+1] = v[i] - (x[i] + x[i+1]) * (h/2)
    return x,v,t   

def Bimann(N , x0 , v0):
    h = t_max / step
    v = np.zeros(step)
    x = np.zeros(step)
    t = np.arange(step) * h 
    x[0] = x0
    x[1] = x0 + v0 * h 
    v[0] = v0
    for i in range(1, step-1):
        x[i+1] = x[i] + v[i] * h - ( 4 * x[i] - x[i-1]) * (h**2 /6)
        v[i+1] = v[i] - h/6 * (2 * x[i+1] + 5 * x[i] - x[i-1])
    return x,v,t

# %%
period = 2 * np.pi
t_max  = 10 * period
x_0    = 0.5
v_0    = 0


step = int(1e4)
euler_x, euler_v, euler_t = euler(step, x_0, v_0)
euler_kremer_x, euler_kremer_v, euler_kremer_t = euler_kremer(step, x_0, v_0)
verlet_x, verlet_v, verlet_t = verlet(step, x_0, v_0)
fast_verlet_x, fast_verlet_v, fast_verlet_t = fast_verlet(step, x_0, v_0)
Bimann_x, Bimann_v, Bimann_t = Bimann(step, x_0, v_0)

# %%
plt.plot(euler_t, euler_x, alpha = 0.7, label = 'Euler')
plt.plot(euler_kremer_t, euler_kremer_x, alpha = 0.7, label = 'Euler-Kremer')
plt.plot(verlet_t, verlet_x, alpha = 0.7, label = 'Verlet')
plt.plot(fast_verlet_t, fast_verlet_x, alpha = 0.7, label = 'Fast Verlet')
plt.plot(Bimann_t, Bimann_x, alpha = 0.7, label = 'Bimann')

plt.title("x dynamic for different algorithms")
plt.xlabel("$t$")
plt.ylabel("$x(t)$")
plt.legend()

plt.savefig("SHO.png")

# %%
plt.plot(euler_x, euler_v, c = 'orange')
plt.title("Path in phase space\n Euler")
plt.ylabel("$\dot{x}$")
plt.xlabel("$x$")

plt.savefig("phase01.png")

# %%
plt.plot(euler_kremer_x, euler_kremer_v, c = 'purple')
plt.title("Path in phase space\n Euler-Kremer")
plt.ylabel("$\dot{x}$")
plt.xlabel("$x$")

plt.savefig("phase02.png")

# %%
plt.plot(verlet_x, verlet_v, c = 'forestgreen')
plt.title("Path in phase space\n Verlet")
plt.ylabel("$\dot{x}$")
plt.xlabel("$x$")

plt.savefig("phase03.png")

# %%
plt.plot(fast_verlet_x, fast_verlet_v, c = 'firebrick')
plt.title("Path in phase space\n Fast Verlet")
plt.ylabel("$\dot{x}$")
plt.xlabel("$x$")

plt.savefig("phase04.png")

# %%
plt.plot(Bimann_x, Bimann_v, c = 'olivedrab')
plt.title("Path in phase space\n Bimann")
plt.ylabel("$\dot{x}$")
plt.xlabel("$x$")

plt.savefig("phase05.png")
